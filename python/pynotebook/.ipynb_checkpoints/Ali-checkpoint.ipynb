# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5])

# %%
y = np.array([4, 5, 6, 7, 8])

# %%
plt.scatter(x, y)

# %%
plt.plot(x, y)
